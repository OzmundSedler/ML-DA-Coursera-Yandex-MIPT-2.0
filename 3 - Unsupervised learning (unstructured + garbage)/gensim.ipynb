# %% [markdown]
# # Пример использования библиотеки gensim для тематического моделирования

# %% [markdown]
# Такая полезная теорема Байеса! :)
#
# ![comic1](http://imgs.xkcd.com/comics/seashell.png)

# %%
from gensim import corpora, models

# %%
from importlib.machinery import SourceFileLoader
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
PROJ = "My Drive/"

PROJECT_PATH = join(ROOT, PROJ)

drive.mount(ROOT, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Импортируем данные в формте UCI Bag of Words
data = corpora.UciCorpus(PROJECT_PATH+"docword.xkcd.txt", PROJECT_PATH+"vocab.xkcd.txt")
dictionary = data.create_dictionary()
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Training

# %%
# обучение модель
# %time ldamodel = models.ldamodel.LdaModel(data, id2word=dictionary, num_topics=5, passes=20, alpha=1.25, eta=1.25)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 22.6 s, sys: 85.6 ms, total: 22.6 s
# Wall time: 22.7 s

# %%
# Сохранение модели
ldamodel.save("ldamodel_xkcd")
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# Загрузка модели
ldamodel = models.ldamodel.LdaModel.load("ldamodel_xkcd")
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# выводим топы слов
for t, top_words in ldamodel.print_topics(num_topics=10, num_words=10):
    print (f'Topic {t} : {top_words}')
# Out:
# Topic 0 : 0.002*"b'wait'" + 0.002*"b'person'" + 0.002*"b'sagal'" + 0.001*"b'peter'" + 0.001*"b'error'" + 0.001*"b'student'" + 0.001*"b'dont'" + 0.001*"b'chrome'" + 0.001*"b'degree'" + 0.001*"b'centigrade'"
# Topic 1 : 0.002*"b'part'" + 0.002*"b'within'" + 0.002*"b'one'" + 0.001*"b'goggles'" + 0.001*"b'relation'" + 0.001*"b'jelly'" + 0.001*"b'accurate'" + 0.001*"b'link'" + 0.001*"b'bean'" + 0.001*"b'found'"
# Topic 2 : 0.004*"b'text'" + 0.004*"b'line'" + 0.004*"b'title'" + 0.004*"b'labeled'" + 0.003*"b'day'" + 0.003*"b'graph'" + 0.002*"b'number'" + 0.002*"b'student'" + 0.002*"b'teacher'" + 0.002*"b'one'"
# Topic 3 : 0.002*"b'male'" + 0.002*"b'island'" + 0.001*"b'paul'" + 0.001*"b'ron'" + 0.001*"b'female'" + 0.001*"b'han'" + 0.001*"b'map'" + 0.001*"b'north'" + 0.001*"b'blogs'" + 0.001*"b'unallocated'"
# Topic 4 : 0.024*"b'man'" + 0.012*"b'person'" + 0.012*"b'text'" + 0.010*"b'title'" + 0.010*"b'woman'" + 0.008*"b'guy'" + 0.006*"b'one'" + 0.006*"b'girl'" + 0.005*"b'just'" + 0.005*"b'two'"

# %%
# Вычисляем логарифм перплексии и немного преобразуем, чтобы привести к общепринятому виду
perplexity = ldamodel.log_perplexity(list(data))
print (2**(-perplexity))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 352.023646649004

# %%
perp = ldamodel.bound(data)
2**(-perp/float(87409))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 352.02365333348473

# %%
# Добавление в модель новых документов, содержащихся в новом корупсе data2
ldamodel.update(data2, passes=10)

# %%
# Получение распределения тем для конкретного документа
doc = list(data)[0]
ldamodel.get_document_topics(doc)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# [(0, 0.056746878),
#  (1, 0.055212304),
#  (2, 0.064758725),
#  (3, 0.05488836),
#  (4, 0.7683937)]

# %% [markdown]
# Эти люди не знают про тематические модели:
#
# ![comic2](http://imgs.xkcd.com/comics/the_problem_with_wikipedia.png) | ![comic3](http://imgs.xkcd.com/comics/mystery_news.png)
